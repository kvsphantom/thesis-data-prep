# %%
import numpy as np
import pandas as pd
import cPickle
import sys


def reverse_annotation(annotations, grouping):
    res = {}
    for k, v in annotations.items():
        for j in v:
            instr = grouping[j] if j in grouping else j
            if instr not in res:
                res[instr] = set([k])
            else:
                res[instr].add(k)
    return res


def read_annotations(fpath):
    with open(fpath) as f:
        annotations = cPickle.load(f)
    return annotations


def read_groupings(fpath, num):
    groups = pd.read_csv(fpath, index_col=0)
    grouping = dict(zip(groups['Instrument'].values,
                        groups['Group {}'.format(num)].values))
    return grouping


def num_nonrare_inst(rannotation, thres):
    d=dict()
    all_songs = set()
    songs = set()
    cnt = 0
    for k, v in rannotation.items():
        all_songs.update(v)
        if len(v) < thres:
            songs.update(v)
        else:
            cnt += 1
            d[k]=len(v)
    print(d)
    return cnt, len(all_songs.difference(songs))

# %%
annotations = read_annotations('annotation_investigator/song_instr.pkl')
grouping = read_groupings('instGroup.csv', 4)
rannotation = reverse_annotation(annotations, grouping)
keys = rannotation.keys()
keys.sort(key=lambda x: len(rannotation[x]))
#for k in keys:
#    print '{}:'.format(k)
#    for i in rannotation[k]:
#        print '    {}'.format(i)
n_nonrare_inst, n_songs_nonrare_inst = num_nonrare_inst(rannotation,
                                                        20)
#print 'Number of songs with no instruments appearing in less than {} songs = {}'. \
#    format(sys.argv[2], n_songs_nonrare_inst)
#print 'Number of instrument appearing in at least {} songs = {}'. \
#    format(sys.argv[2], n_nonrare_inst)
# Out:
# {'electric bass': 63, 'acoustic guitar': 24, 'drum set': 65, 'voice': 64, 'fx/processed sound': 22, 'synthesizer': 27, 'distorted electric guitar': 21, 'violin': 22, 'piano': 43, 'clean electric guitar': 37}

# %%
s = {1,2,3}
s.update({5,4})

# %%
annotations['MusicDelta_Beethoven'] #Same as the info in metadata yaml
# Out:
# {'bassoon',
#  'cello',
#  'clarinet',
#  'double bass',
#  'flute',
#  'french horn',
#  'oboe',
#  'timpani',
#  'trumpet',
#  'viola',
#  'violin section'}

# %%
rannotation
# Out:
# {'Main System': {'JoelHelander_IntheAtticBedroom'},
#  'S07': {'PurlingHiss_Lolita'},
#  'accordion': {'TablaBreakbeatScience_PhaseTransition',
#   'TablaBreakbeatScience_RockSteady',
#   'TablaBreakbeatScience_Scorpio',
#   'TablaBreakbeatScience_Vger',
#   'TablaBreakbeatScience_WhoIsIt'},
#  'acoustic guitar': {'AimeeNorwich_Child',
#   'AlexanderRoss_GoodbyeBolero',
#   'AlexanderRoss_VelvetCurtain',
#   'AmarLal_SpringDay1',
#   'FacesOnFilm_WaitingForGa',
#   'FamilyBand_Again',
#   'HezekiahJones_BorrowedHeart',
#   'HopAlong_SisterCities',
#   'JoelHelander_ExcessiveResistancetoChange',
#   'KarimDouaidy_Hopscotch',
#   'KarimDouaidy_Yatora',
#   'LizNelson_Coldwar',
#   'LizNelson_Rainfall',
#   'Meaxic_YouListen',
#   'MusicDelta_Beatles',
#   'MusicDelta_Country1',
#   'Phoenix_BrokenPledgeChicagoReel',
#   'Phoenix_ColliersDaughter',
#   'Phoenix_ElzicsFarewell',
#   'Phoenix_LarkOnTheStrandDrummondCastle',
#   'Phoenix_ScotchMorris',
# ...
